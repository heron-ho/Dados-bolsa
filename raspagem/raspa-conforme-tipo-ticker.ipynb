# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
#import time

# %%
empresas_acoes = pd.read_excel('empresas_tipos_ticker.xlsx', sheet_name='acoes')
empresas_acoes_tickers = empresas_acoes['symbol'].str.strip()
print(empresas_acoes_tickers)

empresas_bdrs = pd.read_excel('empresas_tipos_ticker.xlsx', sheet_name='bdrs')
empresas_bdrs_tickers = empresas_bdrs['symbol'].str.strip()
print(empresas_bdrs_tickers)

tickers_acoes = empresas_acoes_tickers
tickers_bdrs = empresas_bdrs_tickers
acoes_ou_bdrs = []
cagr_receita_acoes = []
cagr_lucro_acoes = []
contador_acoes = 0
contador_bdrs = 0
# Out:
# 0       AGRO3
# 1       RAIL3
# 2       ALPA3
# 3       ALPA4
# 4       AMAR3
#         ...
# 372    DMAC11
# 373    TFOF11
# 374    BMGB11
# 375     BMGB4
# 376    RBCO11
# Name: symbol, Length: 377, dtype: object
# 0       ALSO3
# 1       BPHA3
# 2       B3SA3
# 3       CCRO3
# 4       CEDO4
#         ...
# 366    IBFF11
# 367    CVBI11
# 368    HRDF11
# 369    RSPD11
# 370    TCPF11
# Name: symbol, Length: 371, dtype: object

# %%
# 1 - faz requisição para acoes
for ticker_acao in tickers_acoes:
    contador_acoes += 1
    link = "https://statusinvest.com.br/acoes/"+ticker_acao # VARIA: "bdrs" e "acoes"
    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"}
    requisicao = requests.get(link, headers=headers)
    site = BeautifulSoup(requisicao.text, "html.parser")
    print(f'item {contador_acoes}: {requisicao}')
    
    # 2 - Coletando os dados (raspagem)
    div1 = site.find("div", title="O CAGR (Compound Annual Growth Rate), ou taxa de crescimento anual composta, é a taxa de retorno necessária para um investimento crescer de seu saldo inicial para o seu saldo final.")
    Strong_da_div1 = div1.find("strong").text

    div2 = site.find_all("div", title="O CAGR (Compound Annual Growth Rate), ou taxa de crescimento anual composta, é a taxa de retorno necessária para um investimento crescer de seu saldo inicial para o seu saldo final.")[1]
    Strong_da_div2 = div2.find("strong").text
    
    print(print(f"INDICADOR DE CRESCIMENTO:\nCAGR receita ultimos 5 anos: {Strong_da_div1},\nCAGR lucro ultimos 5 anos: {Strong_da_div2}"))
    
    cagr_receita_acoes.append(Strong_da_div1)
    cagr_lucro_acoes.append(Strong_da_div2)
# Out:
# item 13: <Response [200]>
# INDICADOR DE CRESCIMENTO:
# CAGR receita ultimos 5 anos: 27,22%,
# CAGR lucro ultimos 5 anos: 15,22%
# None
# item 14: <Response [200]>
# INDICADOR DE CRESCIMENTO:
# CAGR receita ultimos 5 anos: 10,60%,
# CAGR lucro ultimos 5 anos: -%
# None
# item 15: <Response [200]>
# INDICADOR DE CRESCIMENTO:
# CAGR receita ultimos 5 anos: 2,36%,
# CAGR lucro ultimos 5 anos: -%
# None
# item 16: <Response [200]>
# INDICADOR DE CRESCIMENTO:
# CAGR receita ultimos 5 anos: 2,36%,
# CAGR lucro ultimos 5 anos: -%
# None
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\Héron H. Oliveira\Desktop\NEO\Obtendo dados financeiros\Dados-bolsa\raspagem\raspa-conforme-tipo-ticker.ipynb Cell 3 line 6
# ...

# %%
# obterndo retornos para bdr

for ticker_bdr in tickers_bdrs:
    contador_bdrs += 1
    link = "https://statusinvest.com.br/bdrs/"+ticker_bdr # VARIA: "bdrs" e "acoes"
    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"}
    requisicao = requests.get(link, headers=headers)
    site = BeautifulSoup(requisicao.text, "html.parser")
    print(f'item {contador_bdrs}: {requisicao}')
# Out:
# item 1: <Response [200]>
# item 2: <Response [200]>
# item 3: <Response [200]>
# item 4: <Response [200]>
# item 5: <Response [200]>
# item 6: <Response [200]>
# item 7: <Response [200]>
# item 8: <Response [200]>
# item 9: <Response [200]>
# item 10: <Response [200]>
# item 11: <Response [200]>
# item 12: <Response [200]>
# item 13: <Response [200]>
# item 14: <Response [200]>
# item 15: <Response [200]>
# item 16: <Response [200]>
# item 17: <Response [200]>
# item 18: <Response [200]>
# item 19: <Response [200]>
# item 20: <Response [200]>
# item 21: <Response [200]>
# item 22: <Response [200]>
# item 23: <Response [200]>
# item 24: <Response [200]>
# item 25: <Response [200]>
# item 26: <Response [200]>
# item 27: <Response [200]>
# item 28: <Response [200]>
# item 29: <Response [200]>
# item 30: <Response [200]>
# item 31: <Response [200]>
# item 32: <Response [200]>
# item 33: <Response [200]>
# item 34: <Response [200]>
# item 35: <Response [200]>
# item 36: <Response [200]>
# ...
