# %%
import pandas as pd
#from alpha_vantage
# key = T0OWW8AK2OL9HYXI
# Out:
#   Cell In[3], line 2
#     from alpha_vanta
#                     ^
# SyntaxError: invalid syntax

# %%
# - obtendo dados de empresas americanas (alpha-vantage não trabalha com emrpesas brasileiras):

empresas_eua = pd.read_excel('nasdaq_screener_1701886650653.xlsx')
empresas_eua
# Out:
#      Symbol                                              Name Last Sale  \
# 0      AACG  ATA Creativity Global American Depositary Shares   $0.8401
# 1      AACI           Armada Acquisition Corp. I Common Stock    $10.78
# 2     AACIW                Armada Acquisition Corp. I Warrant   $0.0253
# 3      AADI                 Aadi Bioscience Inc. Common Stock     $4.84
# 4       AAL         American Airlines Group Inc. Common Stock   $13.675
# ...     ...                                               ...       ...
# 4161  ZURAW                         Zura Bio Limited Warrants    $0.528
# 4162   ZVRA              Zevra Therapeutics Inc. Common Stock     $4.97
# 4163   ZVSA            ZyVersa Therapeutics Inc. Common Stock     $2.28
# 4164   ZYME                       Zymeworks Inc. Common Stock     $9.22
# 4165   ZYXI                           Zynex Inc. Common Stock    $8.395
#
#       Net Change  % Change    Market Cap         Country  IPO Year    Volume  \
# ...

# %%
key = 'T0OWW8AK2OL9HYXI'

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=IBM&apikey=demo'
r = requests.get(url)
data = r.json()
#print(data)
              
df_meta = pd.json_normalize(data, sep='_')
display(df_meta)
# Out:
#                             Meta Data_1. Information Meta Data_2. Symbol  \
# 0  Daily Prices (open, high, low, close) and Volumes                 IBM
#
#   Meta Data_3. Last Refreshed Meta Data_4. Output Size Meta Data_5. Time Zone  \
# 0                  2023-12-05                  Compact             US/Eastern
#
#   Time Series (Daily)_2023-12-05_1. open  \
# 0                               160.7600
#
#   Time Series (Daily)_2023-12-05_2. high  \
# 0                               162.4700
#
#   Time Series (Daily)_2023-12-05_3. low  \
# 0                              160.7200
#
#   Time Series (Daily)_2023-12-05_4. close  \
# 0                                161.3900
#
#   Time Series (Daily)_2023-12-05_5. volume  ...  \
# 0                                  4556668  ...
#
#   Time Series (Daily)_2023-07-18_1. open  \
# 0                               134.7100
#
#   Time Series (Daily)_2023-07-18_2. high  \
# 0                               135.9500
#
# ...

# %%
url = 'https://www.alphavantage.co/query?function=CASH_FLOW&symbol=IBM&apikey=demo'
r = requests.get(url)
data_cf = r.json()
display(data_cf)

# extrair lista de relatórios anuais
annual_reports = data_cf['annualReports']

# criar um dataframe a partir dos dados
df = pd.json_normalize(annual_reports)

# adicionar a coluna 'symbol' ao DataFrame
df['symbol'] = data_cf['symbol']

# reorganizar as colunas
df = df[['symbol', 'fiscalDateEnding', 'reportedCurrency', 'operatingCashflow', 'paymentsForOperatingActivities', 'proceedsFromOperatingActivities']]
df = pd.DataFrame(df)
# exibir DataFrame
display(df)
# Out:
# {'symbol': 'IBM',
#  'annualReports': [{'fiscalDateEnding': '2022-12-31',
#    'reportedCurrency': 'USD',
#    'operatingCashflow': '10435000000',
#    'paymentsForOperatingActivities': '2430000000',
#    'proceedsFromOperatingActivities': 'None',
#    'changeInOperatingLiabilities': '213000000',
#    'changeInOperatingAssets': '468000000',
#    'depreciationDepletionAndAmortization': '4802000000',
#    'capitalExpenditures': '1346000000',
#    'changeInReceivables': '539000000',
#    'changeInInventory': '-71000000',
#    'profitLoss': '1639000000',
#    'cashflowFromInvestment': '-4202000000',
#    'cashflowFromFinancing': '-4958000000',
#    'proceedsFromRepaymentsOfShortTermDebt': '217000000',
#    'paymentsForRepurchaseOfCommonStock': 'None',
#    'paymentsForRepurchaseOfEquity': 'None',
#    'paymentsForRepurchaseOfPreferredStock': 'None',
#    'dividendPayout': '5948000000',
#    'dividendPayoutCommonStock': '5948000000',
#    'dividendPayoutPreferredStock': 'None',
# ...
